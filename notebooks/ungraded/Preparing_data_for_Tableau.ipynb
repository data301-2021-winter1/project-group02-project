# %% [markdown]
# ## Move it to "notebooks" folder to make imported functions to work!!!

# %%
import numpy as np
import pandas as pd
import project_functions1 as p1

# %%
pathRaw = '../data/raw/recent-grads.csv'
rawData = p1.load_raw(pathRaw)
rawData.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
major_cat_list = rawData['Major_category'].unique()
print(len(major_cat_list))
# Out:
# 16

# %%
major_cat_list = np.sort(major_cat_list)
major_cat_list
# Out:
# array(['Agriculture & Natural Resources', 'Arts',
#        'Biology & Life Science', 'Business',
#        'Communications & Journalism', 'Computers & Mathematics',
#        'Education', 'Engineering', 'Health', 'Humanities & Liberal Arts',
#        'Industrial Arts & Consumer Services', 'Interdisciplinary',
#        'Law & Public Policy', 'Physical Sciences',
#        'Psychology & Social Work', 'Social Science'], dtype=object)

# %%
count = 0
program_num = []
for i in range( len(major_cat_list) ):
    for k in rawData['Major_category']:
        if major_cat_list[i] == k:
            count += 1
    print(major_cat_list[i], "=", count)
    program_num.append(count)
    count = 0
print(program_num)
# Out:
# Agriculture & Natural Resources = 10
# Arts = 8
# Biology & Life Science = 14
# Business = 13
# Communications & Journalism = 4
# Computers & Mathematics = 11
# Education = 16
# Engineering = 29
# Health = 12
# Humanities & Liberal Arts = 15
# Industrial Arts & Consumer Services = 7
# Interdisciplinary = 1
# Law & Public Policy = 5
# Physical Sciences = 10
# Psychology & Social Work = 9
# Social Science = 9
# [10, 8, 14, 13, 4, 11, 16, 29, 12, 15, 7, 1, 5, 10, 9, 9]

# %%
cdf = p1.process_data(pathRaw)
cdf = p1.group_by_majorCat(cdf)
cdf
# Out:
#                          Major_category      Total       Men     Women  \
# 0       Agriculture & Natural Resources    75620.0   40357.0   35263.0
# 1                                  Arts   357130.0  134390.0  222740.0
# 2                Biology & Life Science   453862.0  184919.0  268943.0
# 3                              Business  1302376.0  667852.0  634524.0
# 4           Communications & Journalism   392601.0  131921.0  260680.0
# 5               Computers & Mathematics   299008.0  208725.0   90283.0
# 6                             Education   559129.0  103526.0  455603.0
# 7                           Engineering   537583.0  408307.0  129276.0
# 8                                Health   463230.0   75517.0  387713.0
# 9             Humanities & Liberal Arts   713468.0  272846.0  440622.0
# 10  Industrial Arts & Consumer Services   229792.0  103781.0  126011.0
# 11                    Interdisciplinary    12296.0    2817.0    9479.0
# ...

# %%
cdf["Correct_Unemployment_Rate"] = ( cdf["Unemployed"] / cdf["Total"] )
cdf.head()
# Out:
#                     Major_category      Total       Men     Women  Employed  \
# 0  Agriculture & Natural Resources    75620.0   40357.0   35263.0     63794
# 1                             Arts   357130.0  134390.0  222740.0    288114
# 2           Biology & Life Science   453862.0  184919.0  268943.0    302797
# 3                         Business  1302376.0  667852.0  634524.0   1088742
# 4      Communications & Journalism   392601.0  131921.0  260680.0    330660
#
#    Unemployed  Unemployment_rate  Median   P25th   P75th  College_jobs  \
# 0        3486           0.466352  316000  222000  410100         18677
# 1       28228           0.721382  264500  175700  349300         94785
# 2       22854           0.852849  509900  372600  645200        151233
# 3       79877           0.923826  566000  435000  713000        148538
# 4       26852           0.302151  138000  105000  179900         86556
#
#    Non_college_jobs  Low_wage_jobs  Amount_of_Programs  \
# ...

# %%
cdf["College_Jobs_%"] = ( cdf['College_jobs'] / cdf['Total'] )
cdf
# Out:
#                          Major_category      Total       Men     Women  \
# 0       Agriculture & Natural Resources    75620.0   40357.0   35263.0
# 1                                  Arts   357130.0  134390.0  222740.0
# 2                Biology & Life Science   453862.0  184919.0  268943.0
# 3                              Business  1302376.0  667852.0  634524.0
# 4           Communications & Journalism   392601.0  131921.0  260680.0
# 5               Computers & Mathematics   299008.0  208725.0   90283.0
# 6                             Education   559129.0  103526.0  455603.0
# 7                           Engineering   537583.0  408307.0  129276.0
# 8                                Health   463230.0   75517.0  387713.0
# 9             Humanities & Liberal Arts   713468.0  272846.0  440622.0
# 10  Industrial Arts & Consumer Services   229792.0  103781.0  126011.0
# 11                    Interdisciplinary    12296.0    2817.0    9479.0
# ...

# %%
cdf.to_csv("../data/processed/data_processed1.csv")
