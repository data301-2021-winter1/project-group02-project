# %% [markdown]
# # Charvie Yadav

# %% [markdown]
# ## Research question/interests
#
# In this notebook, I will be analyzing the relationships between gender, major and employment rates. Keeping in mind the research question, I will consider trends between these variables by plotting graphs that will showcase the intertwining relationship between them.

# %% [markdown]
# Hence, I will focus on answering our project's overall research question: Is a college major worth it?

# %% [markdown]
# ## Task 1: ##
# ## Analyzing Gender, Major and Employment Rates ##

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style="ticks",
              font_scale=1.3, 
             )
plt.rc("axes.spines", top=False, right=False)

# %%
data = pd.read_csv("C:/Users/yadav/Desktop/DATA 301/archive (1)/recent-grads.csv")

# %%
data.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
data.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  ...  \
# 168    Biology & Life Science    0.637293           47      6259  ...
# 169  Psychology & Social Work    0.817099            7      2125  ...
# 170  Psychology & Social Work    0.799859           13      2101  ...
# 171  Psychology & Social Work    0.798746           21      3777  ...
# 172                 Education    0.877960            2       742  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
data.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
print("These are all the columns in the dataset")
data.columns
# Out:
# These are all the columns in the dataset
# Index(['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women',
#        'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Rank                    173
# Major_code              173
# Major                   173
# Total                   172
# Men                     172
# Women                   171
# Major_category           16
# ShareWomen              172
# Sample_size             147
# Employed                171
# Full_time               173
# Part_time               170
# Full_time_year_round    173
# Unemployed              161
# Unemployment_rate       169
# Median                   59
# P25th                    48
# P75th                    54
# College_jobs            173
# Non_college_jobs        173
# Low_wage_jobs           166
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Major_code              0
# Major                   0
# Total                   1
# Men                     1
# Women                   1
# Major_category          0
# ShareWomen              1
# Sample_size             0
# Employed                0
# Full_time               0
# Part_time               0
# Full_time_year_round    0
# Unemployed              0
# Unemployment_rate       0
# Median                  0
# P25th                   0
# P75th                   0
# College_jobs            0
# Non_college_jobs        0
# Low_wage_jobs           0
# dtype: int64

# %%
data['Major_category'].unique()
# Out:
# array(['Engineering', 'Business', 'Physical Sciences',
#        'Law & Public Policy', 'Computers & Mathematics',
#        'Agriculture & Natural Resources',
#        'Industrial Arts & Consumer Services', 'Arts', 'Health',
#        'Social Science', 'Biology & Life Science', 'Education',
#        'Humanities & Liberal Arts', 'Psychology & Social Work',
#        'Communications & Journalism', 'Interdisciplinary'], dtype=object)

# %% [markdown]
# ## Task 2 and 3: ##

# %% [markdown]
# ## Cleaning the Data

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Major_code              0
# Major                   0
# Total                   1
# Men                     1
# Women                   1
# Major_category          0
# ShareWomen              1
# Sample_size             0
# Employed                0
# Full_time               0
# Part_time               0
# Full_time_year_round    0
# Unemployed              0
# Unemployment_rate       0
# Median                  0
# P25th                   0
# P75th                   0
# College_jobs            0
# Non_college_jobs        0
# Low_wage_jobs           0
# dtype: int64

# %% [markdown]
# The values with 1 are the data points that need to be dropped

# %%
is_null = data.isnull() 
row_has_null = is_null.any(axis=1)
rows_with_null = data[row_has_null]
rows_with_null
# Out:
#     Rank  Major_code         Major  Total  Men  Women  \
# 21    22        1104  FOOD SCIENCE    NaN  NaN    NaN
#
#                      Major_category  ShareWomen  Sample_size  Employed  ...  \
# 21  Agriculture & Natural Resources         NaN           36      3149  ...
#
#     Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 21       1121                  1735         338           0.096931   53000
#
#     P25th  P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 21  32000  70000          1183              1274            485
#
# [1 rows x 21 columns]

# %%
#dropping data

# %%
data.drop(["Major_code","Low_wage_jobs"], axis=1)
# Out:
#      Rank                                      Major    Total      Men  \
# 0       1                      PETROLEUM ENGINEERING   2339.0   2057.0
# 1       2             MINING AND MINERAL ENGINEERING    756.0    679.0
# 2       3                  METALLURGICAL ENGINEERING    856.0    725.0
# 3       4  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0   1123.0
# 4       5                       CHEMICAL ENGINEERING  32260.0  21239.0
# ..    ...                                        ...      ...      ...
# 168   169                                    ZOOLOGY   8409.0   3050.0
# 169   170                     EDUCATIONAL PSYCHOLOGY   2854.0    522.0
# 170   171                        CLINICAL PSYCHOLOGY   2838.0    568.0
# 171   172                      COUNSELING PSYCHOLOGY   4626.0    931.0
# 172   173                            LIBRARY SCIENCE   1098.0    134.0
#
#        Women            Major_category  ShareWomen  Sample_size  Employed  \
# ...

# %%
data.drop(["Major_code","Low_wage_jobs"], axis=1)
# Out:
#      Rank                                      Major    Total      Men  \
# 0       1                      PETROLEUM ENGINEERING   2339.0   2057.0
# 1       2             MINING AND MINERAL ENGINEERING    756.0    679.0
# 2       3                  METALLURGICAL ENGINEERING    856.0    725.0
# 3       4  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0   1123.0
# 4       5                       CHEMICAL ENGINEERING  32260.0  21239.0
# ..    ...                                        ...      ...      ...
# 168   169                                    ZOOLOGY   8409.0   3050.0
# 169   170                     EDUCATIONAL PSYCHOLOGY   2854.0    522.0
# 170   171                        CLINICAL PSYCHOLOGY   2838.0    568.0
# 171   172                      COUNSELING PSYCHOLOGY   4626.0    931.0
# 172   173                            LIBRARY SCIENCE   1098.0    134.0
#
#        Women            Major_category  ShareWomen  Sample_size  Employed  \
# ...

# %% [markdown]
# # Method Chaining

# %%
import project_functions3 as p3

# %%
data ='C:/Users/yadav/Desktop/DATA 301/archive (1)/recent-grads.csv'
data_unprocessed = p3.unprocessed(data)
data_unprocessed
# Out:
#      Rank  Major_code                                      Major    Total  \
# 0       1        2419                      PETROLEUM ENGINEERING   2339.0
# 1       2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2       3        2415                  METALLURGICAL ENGINEERING    856.0
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4       5        2405                       CHEMICAL ENGINEERING  32260.0
# ..    ...         ...                                        ...      ...
# 168   169        3609                                    ZOOLOGY   8409.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                            LIBRARY SCIENCE   1098.0
#
#          Men    Women            Major_category  ShareWomen  Sample_size  \
# ...

# %%
data_processed = p3.load_process(data)
data_processed
# Out:
#      Rank  Major_code                                  Major     Total  \
# 0      64        1101  AGRICULTURE PRODUCTION AND MANAGEMENT   14240.0
# 1     108        1303           NATURAL RESOURCES MANAGEMENT   13773.0
# 2     112        1302                               FORESTRY    3607.0
# 3      65        1100                    GENERAL AGRICULTURE   10399.0
# 4     144        1105             PLANT SCIENCE AND AGRONOMY    7416.0
# ..    ...         ...                                    ...       ...
# 167    69        5599          MISCELLANEOUS SOCIAL SCIENCES    3283.0
# 168   103        5503                            CRIMINOLOGY   19879.0
# 169   143        5500                GENERAL SOCIAL SCIENCES   12920.0
# 170   125        5507                              SOCIOLOGY  115433.0
# 171    57        5505                INTERNATIONAL RELATIONS   28187.0
#
#          Men    Women                   Major_category  ShareWomen  \
# ...

# %% [markdown]
# ## Task 4: ##

# %% [markdown]
# ## Data Analysis & Plotting Graphs ##

# %%
data_processed.dtypes
# Out:
# Rank                      int64
# Major_code                int64
# Major                    object
# Total                   float64
# Men                     float64
# Women                   float64
# Major_category           object
# ShareWomen              float64
# Sample_size               int64
# Employed                  int64
# Full_time                 int64
# Part_time                 int64
# Full_time_year_round      int64
# Unemployed                int64
# Unemployment_rate       float64
# Median                    int64
# P25th                     int64
# P75th                     int64
# College_jobs              int64
# Non_college_jobs          int64
# Low_wage_jobs             int64
# dtype: object

# %%
data_processed.describe(include='int64').T
# Out:
#                       count          mean           std      min       25%  \
# Rank                  172.0     87.377907     49.983181      1.0     44.75
# Major_code            172.0   3895.953488   1679.240095   1100.0   2403.75
# Sample_size           172.0    357.941860    619.680419      2.0     42.00
# Employed              172.0  31355.808140  50777.428650      0.0   3734.75
# Full_time             172.0  26165.767442  42957.122320    111.0   3181.00
# Part_time             172.0   8877.232558  14679.038729      0.0   1013.75
# Full_time_year_round  172.0  19798.843023  33229.227514    111.0   2474.75
# Unemployed            172.0   2428.412791   4121.730452      0.0    299.50
# Median                172.0  40076.744186  11461.388773  22000.0  33000.00
# P25th                 172.0  29486.918605   9190.769927  18500.0  24000.00
# P75th                 172.0  51386.627907  14882.278650  22000.0  41750.00
# ...

# %%
data_processed.describe(include='float64').T
# Out:
#                    count          mean           std    min          25%  \
# Total              172.0  39370.081395  63483.491009  124.0  4549.750000
# Men                172.0  16723.406977  28122.433474  119.0  2177.500000
# Women              172.0  22646.674419  41057.330740    0.0  1778.250000
# ShareWomen         172.0      0.522223      0.231205    0.0     0.336026
# Unemployment_rate  172.0      0.068024      0.030340    0.0     0.050261
#
#                             50%           75%            max
# Total              15104.000000  38909.750000  393735.000000
# Men                 5434.000000  14631.000000  173809.000000
# Women               8386.500000  22553.750000  307087.000000
# ShareWomen             0.534024      0.703299       0.968954
# Unemployment_rate      0.067544      0.087247       0.177226

# %% [markdown]
# ## Plot 1: Full_time jobs for recent grads (men) by major categories ##

# %%
ax = sns.catplot(x="Men",y="Full_time", data = df1, kind ="bar")
ax.fig.set_size_inches(50,5)
plt.show()

# %% [markdown]
# Here I have plotted Men and the full time jobs they've had in all of the respected major categories as color coded.

# %% [markdown]
# It can be observed that Men had the most full time jobs in Social Sciences and almost equal levels of full time jobs in Engineering, law etc.

# %% [markdown]
# To see the reference of the color codes, you can check plot number 3

# %% [markdown]
# ## Plot 2: Full_time jobs for recent grads (women) by major categories ##

# %%
ax = sns.catplot(x="Women",y="Full_time", data = df1, kind ="bar")
ax.fig.set_size_inches(100,5)
plt.show()

# %% [markdown]
# Here I have plotted Women and the full time jobs they've had in all of the respected major categories as color coded below.

# %% [markdown]
# It can be observed that Women had the most full time jobs in Psychology and Social Work and almost equal levels of full time jobs in business, law etc

# %% [markdown]
# Note: Requires zooming into the graph in order to read the x values.

# %% [markdown]
# ## Plot 3: Major Categories and unemployment rate trends ##

# %%
df1 = data_processed[['Major_category', 'Unemployment_rate']]
df1.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unemployment_rate'}>]], dtype=object)

# %% [markdown]
# ## Plot 4: Major Category choosing by Gender ##

# %%
ax2 = sns.catplot(x="Major_category",y="Men", data = df1, kind ="bar")
ax2.fig.set_size_inches(100,5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19980/220322896.py in <module>
# ----> 1 ax2 = sns.catplot(x="Major_category",y="Men", data = df1, kind ="bar")
#       2 ax2.fig.set_size_inches(100,5)
#       3 plt.show()
#
# ~\miniconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\miniconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3790     p = _CategoricalPlotter()
# ...

# %% [markdown]
# The top two most popular majors for men have been Business and Engineering

# %%
ax2 = sns.catplot(x="Major_category",y="Women", data = df1, kind ="bar")
ax2.fig.set_size_inches(100,5)
plt.show()

# %% [markdown]
# The top two most popular majors for women have been Communications / Journalism and Business.

# %%
# double bar graph for percentage of gender by major

# %%
#stacked bar chart
